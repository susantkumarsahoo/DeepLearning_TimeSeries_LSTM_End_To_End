# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_classic.prompts import ChatPromptTemplate   # use langchain.prompts, not langchain_classic

# %%
# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
# Get API key from environment
api_key = os.getenv("GOOGLE_API_KEY")

# %%
# Initialize Gemini model via LangChain
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",   # or gemini-2.0-pro
    google_api_key=api_key
)

# %%
# Define a simple prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI assistant."),
    ("human", "{question}")
])

# %%
# Create a chain
chain = prompt | llm

# %%
# Run chatbot
response = chain.invoke({"question": "ehat is data science?"})
print(response.content)
# Out:
# Data Science is an **interdisciplinary field** that uses **scientific methods, processes, algorithms, and systems** to extract knowledge and insights from structured and unstructured data.
#
# In simpler terms, it's about **turning raw data into actionable insights and predictions.**
#
# Here's a breakdown of what that means:
#
# 1.  **The Goal:** The primary goal of data science is to understand and analyze actual phenomena with data, and to use that understanding to make better decisions, solve complex problems, and predict future outcomes.
#
# 2.  **Interdisciplinary Nature:** Data science sits at the intersection of several fields:
#     *   **Statistics and Mathematics:** For understanding patterns, probability, hypothesis testing, and model evaluation.
#     *   **Computer Science:** For programming (Python, R, SQL), algorithms, data structures, and handling large datasets.
#     *   **Domain Expertise (Business Acumen):** Understanding the specific industry or problem being addressed. This is crucial for asking the right questions and interpreting results meaningfully.
#     *   **Communication & Visualization:** The ability to present complex findings clearly and compellingly to technical and non-technical audiences.
#
# 3.  **Key Steps in the Data Science Process:**
#     *   **Problem Definition:** Understanding the business problem or question to be answered.
#     *   **Data Collection/Acquisition:** Gathering relevant data from various sources (databases, APIs, web scraping, etc.).
#     *   **Data Cleaning & Preparation (Data Wrangling/Munging):** This is often the most time-consuming step (up to 80% of the work!). It involves handling missing values, correcting errors, removing duplicates, transforming data, and ensuring consistency.
#     *   **Exploratory Data Analysis (EDA):** Analyzing data to summarize its main characteristics, often with visual methods. This helps uncover patterns, anomalies, and relationships.
#     *   **Feature Engineering:** Creating new variables from existing ones to improve the performance of models.
#     *   **Model Building & Selection:** Applying statistical models or machine learning algorithms (e.g., regression, classification, clustering, deep learning) to the prepared data.
#     *   **Model Evaluation:** Assessing the performance and accuracy of the chosen model.
#     *   **Deployment & Monitoring:** Putting the model into production and continuously monitoring its performance and making adjustments as needed.
#     *   **Communication & Storytelling:** Presenting findings, insights, and recommendations to stakeholders in an understandable and actionable way.
#
# 4.  **Why is it Important?**
#     *   **Informed Decision-Making:** Helps businesses make data-driven decisions rather than relying on intuition.
#     *   **Predictive Power:** Forecasts future trends, customer behavior, and potential risks.
#     *   **Optimization:** Improves processes, resource allocation, and efficiency.
#     *   **Personalization:** Creates tailored experiences for users (e.g., recommendation systems).
#     *   **Innovation:** Drives the creation of new products and services.
#
# **Examples of Data Science in Action:**
#
# *   **Recommendation Systems:** "Customers who bought this also bought..." (Amazon, Netflix)
# *   **Fraud Detection:** Identifying unusual transactions in banking or insurance.
# *   **Personalized Marketing:** Targeting ads to specific customer segments.
# *   **Medical Diagnosis:** Assisting doctors in identifying diseases from medical images or patient data.
# *   **Self-Driving Cars:** Processing sensor data to navigate and make decisions.
# *   **Financial Forecasting:** Predicting stock prices or market trends.
#
# In essence, data science empowers organizations and individuals to extract valuable knowledge from the ever-growing ocean of data, leading to smarter choices and more innovative solutions.
