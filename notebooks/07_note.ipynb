# %%
print("ok")
# Out:
# ok

# %%
from google import genai
from google.genai import types
from dotenv import load_dotenv

# %%
client = genai.Client()

# %%
from google import genai
from google.genai import types
client = genai.Client()
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="How does AI work?",
    # Remove the config parameter entirely
)
print(response.text)

# %%
print(response.text)
# Out:
# AI, or Artificial Intelligence, fundamentally works by **training computer systems to learn from data, identify patterns, and make decisions or predictions without being explicitly programmed for every single scenario.**
#
# It's a broad field, but here's a breakdown of the core concepts and how different types of AI generally operate:
#
# ### The Core Idea: Learning from Data
#
# Imagine teaching a child to recognize a cat. You don't give them a list of rules like "if it has pointy ears, whiskers, and says 'meow', it's a cat." Instead, you show them many pictures of cats, point them out, and correct them when they're wrong. Eventually, the child learns to identify a cat on their own.
#
# AI works similarly:
#
# 1.  **Data:** AI systems are fed vast amounts of data (images, text, numbers, sounds, etc.). This is like the examples you show the child. The quality and quantity of this data are crucial.
# 2.  **Algorithms/Models:** These are the "learning rules" or mathematical structures that the AI uses to process the data. Different algorithms are suited for different tasks (e.g., one for recognizing images, another for understanding language).
# 3.  **Training:** The algorithm processes the data, looking for patterns, correlations, and relationships. It adjusts its internal parameters (like "weights" and "biases") to minimize errors in its predictions or classifications. This is the "trial and error" phase, where the system learns from its mistakes.
# 4.  **Inference/Prediction:** Once trained, the AI model can then be presented with *new, unseen* data. It applies what it learned during training to make a prediction, classify an item, or generate a response.
#
# ### Key Components of How AI Works:
#
# 1.  **Machine Learning (ML):** This is the most common approach to AI today. It's about building systems that can learn from data.
#     *   **Supervised Learning:** The most common type. The AI is given labeled data (e.g., pictures of cats labeled "cat," pictures of dogs labeled "dog"). It learns to map inputs to outputs.
#         *   **How it works:** Input data (image) + correct answer (label) -> Algorithm adjusts -> Learns to predict label for new images.
#         *   **Examples:** Image recognition, spam detection, predicting house prices.
#     *   **Unsupervised Learning:** The AI is given unlabeled data and has to find patterns or structures on its own.
#         *   **How it works:** Input data (unlabeled) -> Algorithm finds hidden groups/structures.
#         *   **Examples:** Customer segmentation, anomaly detection.
#     *   **Reinforcement Learning:** The AI learns by trial and error through interacting with an environment. It receives rewards for desired actions and penalties for undesirable ones.
#         *   **How it works:** Agent performs action -> Environment gives reward/penalty -> Agent learns optimal strategy.
#         *   **Examples:** Game playing (AlphaGo), robotics, self-driving cars (in simulations).
#
# 2.  **Deep Learning (DL):** A subfield of Machine Learning that uses Artificial Neural Networks (ANNs) with many layers ("deep"). These networks are loosely inspired by the structure of the human brain.
#     *   **How it works:** Instead of relying on humans to hand-craft features (e.g., "this is a cat's ear"), deep neural networks can learn to extract complex features directly from raw data themselves. The "depth" allows them to learn hierarchical representations (e.g., first edges, then shapes, then objects).
#     *   **Examples:** Facial recognition, natural language processing (like ChatGPT), speech recognition, advanced image generation.
#
# 3.  **Natural Language Processing (NLP):** Enables computers to understand, interpret, and generate human language.
#     *   **How it works:** Uses ML/DL models trained on massive text datasets to understand grammar, semantics, context, and even sentiment.
#     *   **Examples:** Translation, chatbots, sentiment analysis, text summarization.
#
# 4.  **Computer Vision:** Enables computers to "see" and interpret visual information from images and videos.
#     *   **How it works:** Uses ML/DL models (especially convolutional neural networks) to identify objects, faces, scenes, and even actions.
#     *   **Examples:** Self-driving cars, medical image analysis, security surveillance, facial recognition.
#
# ### In Simple Terms:
#
# At its heart, AI today is mostly about **complex statistical models** that are incredibly good at finding patterns in vast amounts of data. We feed them data, they build a mathematical representation of that data, and then they use that representation to make educated guesses or decisions on new, similar data.
#
# It's not magic, nor is it conscious (at least not yet for the AI we have today). It's sophisticated engineering and mathematics allowing machines to perform tasks that once required human intelligence.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_classic.prompts import ChatPromptTemplate
from dotenv import load_dotenv
import os

# %%
# Load environment variables from .env file
load_dotenv()
# Get API key from environment
api_key = os.getenv("GOOGLE_API_KEY")

# %%
# Initialize Gemini model via LangChain
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",   # or gemini-2.0-pro
    google_api_key= api_key # or rely on env var
)

# %%
# Define a simple prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI assistant."),
    ("human", "{question}")
])

# %%
# Create a chain
chain = prompt | llm

# %%
# Run chatbot
response01 = chain.invoke({"question": "How does AI work?"})

# %%
print(response01.content)
# Out:
# AI, or Artificial Intelligence, isn't a single technology but rather an umbrella term for machines that can perform tasks that typically require human intelligence. The core idea behind most modern AI is to enable computers to **learn from data** rather than being explicitly programmed for every possible scenario.
#
# Here's a breakdown of how it generally works:
#
# ### The Core Process (Simplified)
#
# Imagine you want to teach a computer to identify cats in pictures:
#
# 1.  **Data Collection & Preparation:**
#     *   **Fuel:** AI needs massive amounts of data. For our cat example, this would be thousands, even millions, of images, some with cats, some without.
#     *   **Labeling:** Crucially, this data often needs to be "labeled." For each picture, a human might tell the AI, "Yes, this is a cat" or "No, this is not a cat." This creates the "ground truth" for the AI to learn from. (This is for *supervised learning*, the most common type).
#     *   **Cleaning:** The data needs to be cleaned, organized, and formatted in a way the computer can understand.
#
# 2.  **Choosing an Algorithm (The "Learning Method"):**
#     *   This is like deciding *how* the AI will learn from the data. There are many different types of algorithms, each suited for different tasks.
#     *   **Machine Learning (ML):** This is the most prevalent approach to AI today. It involves algorithms that allow systems to learn from data.
#         *   **Supervised Learning:** (Our cat example) The AI learns from labeled data to make predictions or classify new data.
#         *   **Unsupervised Learning:** The AI finds patterns or structures in unlabeled data (e.g., grouping similar customers together).
#         *   **Reinforcement Learning:** The AI learns by trial and error, receiving "rewards" for correct actions and "penalties" for incorrect ones (e.g., teaching a robot to walk).
#     *   **Deep Learning (DL):** A powerful *subset* of Machine Learning, inspired by the structure and function of the human brain (hence "neural networks"). Deep learning models have multiple "layers" that can automatically learn complex features from raw data. They are particularly effective for tasks like image recognition, speech recognition, and natural language processing.
#
# 3.  **Training the Model:**
#     *   **Learning Phase:** The chosen algorithm is fed the prepared data. The AI "studies" the data, looking for patterns, correlations, and features that distinguish one category from another (e.g., what visual features make an image a "cat" vs. "not a cat").
#     *   **Adjusting Parameters:** During training, the algorithm adjusts its internal "parameters" (like knobs and dials) to minimize errors in its predictions. It repeatedly tries to predict the labels for the training data and then corrects itself based on the actual labels.
#     *   **Iteration:** This process happens thousands or millions of times until the model gets good at making accurate predictions.
#
# 4.  **Making Predictions/Decisions (Inference):**
#     *   **Deployment:** Once trained, the AI model is ready to be used.
#     *   **New Data:** When you show it a new, unseen picture, it uses the patterns it learned during training to analyze the image and predict whether it contains a cat or not.
#     *   **Output:** It might output "cat" with a certain probability (e.g., "95% sure it's a cat").
#
# 5.  **Evaluation & Refinement:**
#     *   **Performance Check:** AI developers constantly evaluate how well the model performs on new data.
#     *   **Improvements:** If it makes too many mistakes, they might collect more data, refine the labels, choose a different algorithm, or adjust the training process until the AI meets desired performance levels. It's an iterative process.
#
# ### Key Components
#
# *   **Algorithms:** The mathematical recipes and rules that govern how the AI learns and makes decisions.
# *   **Models:** The output of the training process – it's the trained "brain" that has learned from the data and can now make predictions.
# *   **Data:** The raw material (images, text, numbers, audio) that AI learns from. The quality and quantity of data are paramount.
# *   **Hardware:** Powerful processors like GPUs (Graphics Processing Units) and TPUs (Tensor Processing Units) are essential for handling the massive computations involved in training complex AI models.
# *   **Software Frameworks:** Tools like TensorFlow, PyTorch, and Scikit-learn provide ready-made building blocks and environments for developing AI.
#
# ### In essence:
#
# Instead of a programmer writing code for *every possible scenario* (e.g., "if pixel X is red and pixel Y is blue, then it's a nose"), AI is given examples and **learns the rules itself** by identifying patterns in the data. This ability to learn and adapt is what makes AI so powerful and transformative.
